# %% [markdown]
# # Faster Python with Cython
# #### By Shahar Shani-Kadmiel, TU Delft, March 2018
#
# ---
#
# In the following notebook document some key features of [Cython](http://cython.readthedocs.io/en/latest/), which is a programming language that makes writing C extensions for the Python language as easy as Python itself.
#
# ---
#
# <p style="text-align: center;"> View on <a href="https://nbviewer.jupyter.org/github/shaharkadmiel/random_stuff/blob/master/Notebooks/Py-Cy-Nb.ipynb"> Jupyter NBViewer
#     <img src="https://nbviewer.jupyter.org/static/img/nav_logo.svg" width="150">
# </a>
#
# for a propper looking version of this notebook
#
# <br><br>
#
# or on <a href="https://mybinder.org/v2/gh/shaharkadmiel/random_stuff/master?filepath=Notebooks%2FPy-Cy-Nb.ipynb">Binder
#     <img src="https://mybinder.org/static/logo.svg" width="160">
#     <img src="https://mybinder.org/badge.svg">
# </a>
# <b>For a live, interactive version of this notebook</b>
# </p>
#
# ---
#
# I will also compare performance to [Numba](http://numba.pydata.org/numba-doc/latest/index.html), other optimization tools which I covered in a [previous notebook](https://nbviewer.jupyter.org/github/shaharkadmiel/random_stuff/blob/master/Notebooks/optimization_with_Numba.ipynb).
#
# Inside a `jupyter-notebook`, the `Cython` extension is easily accessible with the cell-magic command `%%cython` which turns an entire notebook cell into a cython environment. This forgoes the intermediate compilation step otherwise necessary when extending python code with cython.
#
# This will become clearer as we run through the notebook.
#
# ---
#
# To have the cython magic command we need to load the cython notebook extension which is not loaded by default.

# %%
# %load_ext Cython

# %% [markdown]
# # Fibonacci series example:

# %% [markdown]
# Let's begin with a simple example of the Fibonacci series expansion to the n-th member. This is a nice implementation to test because there is actually very little vectorization that can be done as every iteration depends on the previous 2 members.

# %% [markdown]
# ## Pure Python:
# The pure python implementation would look something like this:

# %%
import numpy as np

def fib_python(n):
    """
    Return the first ``n`` members of the Fibonacci series.
    """
    result = np.empty(n)
    result[:2] = 0, 1
    for n_ in range(2, n):
        result[n_] = result[n_ - 2] + result[n_ - 1]
    return result

# %%
n = 500
result_python = fib_python(n)
print(result_python[-1])
# Out:
# 8.61682916002e+103

# %%
t_fib_python = %timeit -o fib_python(n)
# Out:
# 180 µs ± 10.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ## Simple Cython compilation
# If we simply compile this pure python implementation as `cython` code, there shouldn't be much improvement. I will do this anyway in order to demonstrate the compilation process.
#
# We will write the above implementation to a `.pyx` file and compile it:

# %%
# %%writefile fib_python_compiled.pyx
# import numpy as np
#
# def fib_python_compiled(n):
#     """
#     Return the first ``n`` members of the Fibonacci series.
#     """
#     result = np.empty(n)
#     result[:2] = 0, 1
#     for n_ in range(2, n):
#         result[n_] = result[n_ - 2] + result[n_ - 1]
#     return result
# Out:
# Writing fib_python_compiled.pyx

# %% [markdown]
# Now write the following `setup.py`:

# %%
# %%writefile setup.py
from distutils.core import setup
from Cython.Build import cythonize

setup(
  name = 'Pure Python Fibonacci Expander',
  ext_modules = cythonize('fib_python_compiled.pyx'),
)
# Out:
# Writing setup.py

# %%
ls
# Out:
# Py-Cy-Nb.ipynb
# fib_python_compiled.cpython-36m-darwin.so*
# fib_python_compiled.pyx
# setup.py

# %% [markdown]
# We now build the extension like so:

# %%
# !python setup.py build_ext --inplace
# Out:
# Compiling fib_python_compiled.pyx because it changed.
# [1/1] Cythonizing fib_python_compiled.pyx
# running build_ext
# building 'fib_python_compiled' extension
# creating build
# creating build/temp.macosx-10.9-x86_64-3.6
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include/python3.6m -c fib_python_compiled.c -o build/temp.macosx-10.9-x86_64-3.6/fib_python_compiled.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 build/temp.macosx-10.9-x86_64-3.6/fib_python_compiled.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/Desktop/optimization/fib_python_compiled.cpython-36m-darwin.so

# %%
ls
# Out:
# Py-Cy-Nb.ipynb
# build/
# fib_python_compiled.c
# fib_python_compiled.cpython-36m-darwin.so*
# fib_python_compiled.pyx
# setup.py

# %% [markdown]
# Note that a shared object (`fib_python_compiled.*.so`) has been created by compiling the `c` code (`fib_python_compiled.c`), which was generated in the setup phase.
#
# The setup phase also prints out the specific `gcc` command which was used to compile the code.
#
# You can have a look inside all these files but the only important file is the shared object which provides Python bindings to the compiled `c` code. The other files can be deleted.

# %%
rm -rf build/ fib_python_compiled.c fib_python_compiled.pyx setup.py

# %%
ls
# Out:
# Py-Cy-Nb.ipynb
# fib_python_compiled.cpython-36m-darwin.so*

# %% [markdown]
# Now `fib_python_compiled` can be imported as if it were a regular python function inside a regular python module:

# %%
from fib_python_compiled import fib_python_compiled
print(fib_python_compiled.__doc__)
# Out:
#     Return the first ``n`` members of the Fibonacci series.

# %%
n = 500
result_python_compiled = fib_python_compiled(n)
print(result_python_compiled[-1])
# Out:
# 8.61682916002e+103

# %%
t_fib_python_compiled = %timeit -o fib_python_compiled(n)
# Out:
# 130 µs ± 10 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
print('X{:.2f} Boost'.format(t_fib_python.average /
                             t_fib_python_compiled.average))
# Out:
# X1.38 Boost

# %% [markdown]
# So there is a slight gain in performance just by compiling pure python code and of course results are the same:

# %%
np.allclose(result_python, result_python_compiled)
# Out:
# True

# %%
n = 500
result_python = fib_python(n)
print(result_python[-1])
# Out:
# 8.61682916002e+103

# %% [markdown]
# ## Cython Magic
# Let's see how the cython magic makes our life so much easier:
#
# The process described above had 3 steps:
#
# 1. Write `.pyx` file
# 2. Write `setup.py`
# 3. Compile
#
# With the `%%cython` magic, it is all combined to one step:

# %%
# %%cython -a -f -3 --verbose
# import numpy as np
#
# def fib_python_compiled_magic(n):
#     """
#     Return the first ``n`` members of the Fibonacci series.
#     """
#     result = np.empty(n)
#     result[:2] = 0, 1
#     for n_ in range(2, n):
#         result[n_] = result[n_ - 2] + result[n_ - 1]
#     return result
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_3d04d98fa9df9c3e21f076a663278614.pyx
# building '_cython_magic_3d04d98fa9df9c3e21f076a663278614' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_3d04d98fa9df9c3e21f076a663278614.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_3d04d98fa9df9c3e21f076a663278614.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_3d04d98fa9df9c3e21f076a663278614.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_3d04d98fa9df9c3e21f076a663278614.cpython-36m-darwin.so
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_3d04d98fa9df9c3e21f076a663278614.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %% [markdown]
# Note that a similar output containing the `gcc` compilation command is generated but this time, everything is compiled to the user's `.ipython` directory.
#
# The `-a` option in the `%%cython` command outputs an annotated version of the code and highlight lines with python interaction in yellow. The more yellow the slower the code is.
#
# The function is already available in the python namespace so no need to import:

# %%
result_python_compiled_magic = fib_python_compiled_magic(n)

# %%
n = 500
result_python_compiled_magic = fib_python_compiled_magic(n)
print(result_python_compiled_magic[-1])
# Out:
# 8.61682916002e+103

# %% [markdown]
# and performance should be about the same:

# %%
# %timeit fib_python_compiled_magic(n)
# Out:
# 127 µs ± 4.82 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ## Cython coding
# Till now, we didn't do any `cython` codeing. We simply compiled, or *Cythonized* some python code. We can do much more towards performance by [*static typing*](http://cython.readthedocs.io/en/latest/src/quickstart/cythonize.html) some of our variables and writing slightly smarter code. Let's go through an iterative example of code improvement step by step:

# %% [markdown]
# **Step 1:** *Type* everything you can

# %%
# %%cython -a -f -3 --verbose
#
# import numpy as np
# cimport cython
#
# def fib_cython1(int n):
#     """
#     Return the first ``n`` members of the Fibonacci series.
#     """
#     cdef int n_
#     result = np.empty(n)
#     result[:2] = 0, 1
#     for n_ in range(2, n):
#         result[n_] = result[n_ - 2] + result[n_ - 1]
#     return result
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_89aad38bfe573ccbbafa5dbd1a700970.pyx
# building '_cython_magic_89aad38bfe573ccbbafa5dbd1a700970' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_89aad38bfe573ccbbafa5dbd1a700970.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_89aad38bfe573ccbbafa5dbd1a700970.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_89aad38bfe573ccbbafa5dbd1a700970.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_89aad38bfe573ccbbafa5dbd1a700970.cpython-36m-darwin.so
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_89aad38bfe573ccbbafa5dbd1a700970.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
t_fib_cython1 = %timeit -o fib_cython1(n)
# Out:
# 68.9 µs ± 2.2 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# This is a major improvement!

# %%
print(('X{:.2f} Boost relative to the *non-compiled* python implementation\n'
       'and X{:.2f} relative to the pure python *compiled* implementation').format(
           t_fib_python.average / t_fib_cython1.average,
           t_fib_python_compiled.average / t_fib_cython1.average))
# Out:
# X2.61 Boost relative to the *non-compiled* python implementation
# and X1.89 relative to the pure python *compiled* implementation

# %% [markdown]
# Just by static typing `n` and our iterator variable `_n`.

# %% [markdown]
# **Step 2:** Don't pass arrays back and forth between python and c
#
# ...instead pass a [*memory view*](http://cython.readthedocs.io/en/latest/src/userguide/memoryviews.html) for the compiled code to populate in a shared memory allocation between `python` and `c`:

# %%
# %%cython -a -f -3 --verbose
#
# cimport cython
#
# def fib_cython2(int n, double [:] result):
#     """
#     Return the first ``n`` members of the Fibonacci series.
#     """
#     cdef int n_
#     result[:2] = 0, 1
#     for n_ in range(2, n):
#         result[n_] = result[n_ - 2] + result[n_ - 1]
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_0e341ffb1622913cda78d9645ba69b2d.pyx
# building '_cython_magic_0e341ffb1622913cda78d9645ba69b2d' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_0e341ffb1622913cda78d9645ba69b2d.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_0e341ffb1622913cda78d9645ba69b2d.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_0e341ffb1622913cda78d9645ba69b2d.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_0e341ffb1622913cda78d9645ba69b2d.cpython-36m-darwin.so
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_0e341ffb1622913cda78d9645ba69b2d.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %% [markdown]
# If you try to use `fib_cython2` as it is now, you will get the following error:
#
# ```
# TypeError: a bytes-like object is required, not 'tuple'
# ```
#
# It took me some time to figure out why I am getting this error but as `result` is now a *c-array* view into a shared memory space, it behaves just like a *c-array* which does not support multi-value assignment into an array slice like python.
#
# Let's try this again changing
#
# ```python
# result[:2] = 0, 1
# ```
# in line 9 to:
# ```python
# result[0] = 0
# result[1] = 1
# ```

# %%
# %%cython -a -f -3 --verbose
#
# cimport cython
#
# def fib_cython2_1(int n, double [:] result):
#     """
#     Return the first ``n`` members of the Fibonacci series.
#     """
#     cdef int n_
#     result[0] = 0  # <--- single value assigned to a single index
#     result[1] = 1  # <--- single value assigned to a single index
#     for n_ in range(2, n):
#         result[n_] = result[n_ - 2] + result[n_ - 1]
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_461fe321232cae29e4288259d422aaf3.pyx
# building '_cython_magic_461fe321232cae29e4288259d422aaf3' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_461fe321232cae29e4288259d422aaf3.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_461fe321232cae29e4288259d422aaf3.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_461fe321232cae29e4288259d422aaf3.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_461fe321232cae29e4288259d422aaf3.cpython-36m-darwin.so
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_461fe321232cae29e4288259d422aaf3.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
# %%timeit -o
result_cython2_1 = np.empty(n, np.double)
fib_cython2_1(n, result_cython2_1)
# Out:
# 3.84 µs ± 328 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# <TimeitResult : 3.84 µs ± 328 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)>

# %%
t_fib_cython2 = _

# %%
print(('We just went down from {:.2e} seconds to {:.2e} seconds.\n'
       'A whopping X{:.2f} performance boost relative to step 1.').format(
           t_fib_cython1.average, t_fib_cython2.average,
           t_fib_cython1.average / t_fib_cython2.average))
# Out:
# We just went down from 6.89e-05 seconds to 3.84e-06 seconds.
# A whopping X17.97 performance boost relative to step 1.

# %% [markdown]
# But still, there are quite a bit of yellow lines inside the function. We expect the function call to be yellow because that is where python interacts with cython, but why does indexing through the array causes python interaction?
#
# Turns out that cython checks to make sure indexing does not go out of bounds and it actually goes to python for that. We can tell cython to skip these checks but we then need to make sure we don't go out of bounds...
#
# This is achieved with [*compiler directives*](http://cython.readthedocs.io/en/latest/src/reference/compilation.html#compiler-directives) which can be added in several different ways (see [how to set directives](http://cython.readthedocs.io/en/latest/src/reference/compilation.html#how-to-set-directives)).
#
# **Step 3:** Use compiler directives

# %%
# %%cython -a -f -3 --verbose
# #cython: boundscheck=False
#
# cimport cython
#
# def fib_cython3(int n, double [:] result):
#     """
#     Return the first ``n`` members of the Fibonacci series.
#     """
#     cdef int n_
#     result[0] = 0
#     result[1] = 1
#     for n_ in range(2, n):
#         result[n_] = result[n_ - 2] + result[n_ - 1]
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_ac042c2b2e33995705bcf7b52bc7c3cd.pyx
# building '_cython_magic_ac042c2b2e33995705bcf7b52bc7c3cd' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_ac042c2b2e33995705bcf7b52bc7c3cd.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_ac042c2b2e33995705bcf7b52bc7c3cd.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_ac042c2b2e33995705bcf7b52bc7c3cd.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_ac042c2b2e33995705bcf7b52bc7c3cd.cpython-36m-darwin.so
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_ac042c2b2e33995705bcf7b52bc7c3cd.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
# %%timeit -o
result_cython3 = np.empty(n, np.double)
fib_cython3(n, result_cython3)
# Out:
# 4.04 µs ± 173 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# <TimeitResult : 4.04 µs ± 173 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)>

# %%
t_fib_cython3 = _

# %% [markdown]
# *less yellow is better...*

# %% [markdown]
# How does this compare to Numba?

# %%
import numba as nb
@nb.njit(nb.void(nb.int32, nb.double[:]), cache=True)
def fib_numba(n, result):
    """
    Return the first ``n`` members of the Fibonacci series.
    """
    result[0] = 0.
    result[1] = 1.
    for n_ in range(2, n):
        result[n_] = result[n_ - 2] + result[n_ - 1]

# %%
# %%timeit -o
result_numba = np.empty(n, dtype=np.double)
fib_numba(np.int32(n), result_numba)
# Out:
# 3.93 µs ± 150 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# <TimeitResult : 3.93 µs ± 150 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)>

# %%
t_fib_numba = _

# %% [markdown]
# So Numba is doing quite well too.

# %%
timings = [t_fib_python.average,
           t_fib_python_compiled.average,
           t_fib_cython1.average,
           t_fib_cython2.average,
           t_fib_cython3.average,
           t_fib_numba.average]

t = ['{:.2e}'.format(t) for t in timings]

x = ['{:.2f}'.format(timings[0] / t) for t in timings]

imp = ['Python', 'Compiled Python', 'Cython1', 'Cython2', 'Cython3', 'Numba']

hline = '-' * 45
layout = '| {:<15} | {:>10} | {:>10} |'
print(hline)
print(layout.format('Implementation', 't, seconds', 'boost, X'))
print(hline)

for imp_, t_, x_ in zip(imp, t, x):
      print(layout.format(imp_, t_, x_))
            
print(hline)
# Out:
# ---------------------------------------------
# | Implementation  | t, seconds |   boost, X |
# ---------------------------------------------
# | Python          |   1.80e-04 |       1.00 |
# | Compiled Python |   1.30e-04 |       1.38 |
# | Cython1         |   6.89e-05 |       2.61 |
# | Cython2         |   3.84e-06 |      46.87 |
# | Cython3         |   4.04e-06 |      44.55 |
# | Numba           |   3.93e-06 |      45.73 |
# ---------------------------------------------

# %% [markdown]
# # Sum2D example:
# There is only so much we can do to optimize the Fibonacci series expander because as I mentioned above, every member depends on the previous 2 members and therefor cannot be parallelized with much (or any) improvement it performance.
#
# Let's look at another example:
# We will sum a *M* by *N* array element by element and as always, we will begin with a simple python implementation:

# %%
# %timeit map('{:.2e}'.format, timings)
# %timeit ['{:.2e}'.format(t) for t in timings]
# Out:
# 253 ns ± 11.5 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# 3.35 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %load_ext Cython
import numpy as np
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %% [markdown]
# ## Python implementation

# %%
def sum1d_python(a1d):
    """
    Sum all elements of a 1D array ``a1d``.
    """
    sum_ = 0
    for element in a1d:
        sum_ += element
    return sum_

def sum2d_python(a2d):
    """
    Sum all elements of a 2D array ``a2d``.
    
    Parameters
    ----------
    a2d : array-like
        A 2D array to sum element by element.
        
    Returns
    -------
    sum : float
        The total sum of ``a2d``.
    """
    sum_ = 0
    for row in a2d:
        sum_ += sum1d_python(row)
    return sum_

# %%
M, N = int(1e4), int(1e5)
a = np.random.rand(M, N) - 0.5
print(a.shape, a.dtype)
print('Numpy sum:', a.sum())
# Out:
# (10000, 100000) float64
# Numpy sum: -2661.35914521

# %%
print('sum2d_python sum:', sum2d_python(a))
# Out:
# sum2d_python sum: -2661.35914521

# %%
t_sum2d_python = %timeit -o sum2d_python(a)
# Out:
# 1min 35s ± 2.22 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# This is terrible! We are, however summing 1000000000 elements...
#
# We can use a line profiler to see what part of our code is eating up time:

# %%
# %load_ext line_profiler
l = %lprun -r -f sum2d_python sum2d_python(a)

# %%
l.print_stats(output_unit=1)
# Out:
# Timer unit: 1 s
#
# Total time: 324.839 s
# File: <ipython-input-39-7babcc2ec167>
# Function: sum2d_python at line 10
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     10                                           def sum2d_python(a2d):
#     11                                               """
#     12                                               Sum all elements of a 2D array ``a2d``.
#     13
#     14                                               Parameters
#     15                                               ----------
#     16                                               a2d : array-like
#     17                                                   A 2D array to sum element by element.
#     18
#     19                                               Returns
#     20                                               -------
#     21                                               sum : float
#     22                                                   The total sum of ``a2d``.
#     23                                               """
#     24         1          0.0      0.0      0.0      sum_ = 0
#     25     10001          0.0      0.0      0.0      for row in a2d:
#     26     10000        324.8      0.0    100.0          sum_ += sum1d_python(row)
#     27         1          0.0      0.0      0.0      return sum_

# %% [markdown]
# It is clear that line 26, which calls the `sum1d_python` is taking up most of the time (well ** 100% ! **).

# %% [markdown]
# Let's see what cython can do for us:
#
# ## Cython

# %%
# %%cython -a -f -3 --verbose
#
# cimport cython
#
# def sum1d_cython1(double [:] a1d):
#     """
#     Sum all elements of a 1D array ``a1d``.
#     """
#     cdef:
#         double sum_ = 0
#         int j, ne
#
#     ne = a1d.size
#     for j in range(ne):
#         sum_ += a1d[j]
#     return sum_
#
# def sum2d_cython1(double [:, :] a2d):
#     """
#     Sum all elements of a 2D array ``a2d``.
#
#     Parameters
#     ----------
#     a2d : array-like
#         A 2D array to sum element by element.
#
#     Returns
#     -------
#     sum : float
#         The total sum of ``a2d``.
#     """
#     cdef:
#         double sum_ = 0
#         int i, nr
#
#     nr = a2d.shape[0]
#     for i in range(nr):
#         sum_ += sum1d_cython1(a2d[i])
#     return sum_
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_2565d4b4f344f992c9386add769c226b.pyx
# building '_cython_magic_2565d4b4f344f992c9386add769c226b' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_2565d4b4f344f992c9386add769c226b.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_2565d4b4f344f992c9386add769c226b.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_2565d4b4f344f992c9386add769c226b.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_2565d4b4f344f992c9386add769c226b.cpython-36m-darwin.so
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_2565d4b4f344f992c9386add769c226b.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
print('sum2d_cython1 sum:', sum2d_cython1(a))

t_sum2d_cython1 = %timeit -o sum2d_cython1(a)
# Out:
# sum2d_cython1 sum: -2661.359145210011
# 1.41 s ± 29.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# This is impressive!, we didn't do much, only typed a few variable and we are already getting a huge performance boost.

# %%
print('X{:.2f}'.format(t_sum2d_python.average / t_sum2d_cython1.average))
# Out:
# X67.67

# %% [markdown]
# Note that we now have 2 functions in the above cython module:
#
# - sum2d_cython1, and
# - sum1d_cython1
#
# Both are accessible from python because they are defined with `def`.

# %%
print(sum1d_cython1)
# Out:
# <built-in function sum1d_cython1>

# %% [markdown]
# However, `sum1d_cython1` is only ever called from within cython so we might want to type it as well and get rid of the overhead of python function calls.

# %%
# %%cython -a -f -3 --verbose
# #cython: boundscheck=False
#
# cimport cython
#
# cdef double sum1d_cython2(double [:] a1d, int N):
#     """
#     Sum all elements of a 1D array ``a1d``.
#     """
#     cdef:
#         int j
#         double s_ = 0
#
#     for j in range(N):
#         s_ += a1d[j]
#     return s_
#
# def sum2d_cython2(double [:, :] a2d):
#     """
#     Sum all elements of a 2D array ``a2d``.
#
#     Parameters
#     ----------
#     a2d : array-like
#         A 2D array to sum element by element.
#
#     Returns
#     -------
#     sum : float
#         The total sum of ``a2d``.
#     """
#     cdef:
#         double sum_ = 0
#         int i, M, N
#
#     M = a2d.shape[0]
#     N = a2d.shape[1]
#     for i in range(M):
#         sum_ += sum1d_cython2(a2d[i], N)
#     return sum_
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_729b8199daa3fbbb7c8b99738fa9546d.pyx
# building '_cython_magic_729b8199daa3fbbb7c8b99738fa9546d' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_729b8199daa3fbbb7c8b99738fa9546d.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_729b8199daa3fbbb7c8b99738fa9546d.o
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_729b8199daa3fbbb7c8b99738fa9546d.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_729b8199daa3fbbb7c8b99738fa9546d.cpython-36m-darwin.so
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_729b8199daa3fbbb7c8b99738fa9546d.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
print('sum2d_cython2 sum:', sum2d_cython2(a))

t_sum2d_cython2 = %timeit -o sum2d_cython2(a)
# Out:
# sum2d_cython2 sum: -2661.359145210011
# 1.37 s ± 13.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# So even though we did not gain any performance boost by typing the `sum1d_cython2` function, it is now possible to parallelize this function because it is a c-only function.
#
# However, `sum1d_cython2` is not exposed to the python user anymore.

# %% [markdown]
# ## Parallel implementation
# The `--compile-args=-fopenmp --link-args=-fopenmp` extra flags need to be added:

# %%
# %%cython -a -f -3 --verbose --compile-args=-fopenmp --link-args=-fopenmp
# #cython: boundscheck=False
#
# cimport cython
# from cython.parallel cimport prange
#
# cdef double sum1d_cython_parallel(double [:] a1d, int N) nogil:
#     """
#     Sum all elements of a 1D array ``a1d``.
#     """
#     cdef:
#         int j
#         double s_ = 0
#
#     for j in prange(N):
#         s_ += a1d[j]
#     return s_
#
# def sum2d_cython_parallel(double [:, :] a2d):
#     """
#     Sum all elements of a 2D array ``a2d``.
#
#     Parameters
#     ----------
#     a2d : array-like
#         A 2D array to sum element by element.
#
#     Returns
#     -------
#     sum : float
#         The total sum of ``a2d``.
#     """
#     cdef:
#         double sum_ = 0
#         int i, M, N
#
#     M = a2d.shape[0]
#     N = a2d.shape[1]
#     for i in range(M):
#         sum_ += sum1d_cython_parallel(a2d[i], N)
#     return sum_
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_d34791f82efcf31cce664073d73b50a7.pyx
# building '_cython_magic_d34791f82efcf31cce664073d73b50a7' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_d34791f82efcf31cce664073d73b50a7.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_d34791f82efcf31cce664073d73b50a7.o -fopenmp
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_d34791f82efcf31cce664073d73b50a7.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_d34791f82efcf31cce664073d73b50a7.cpython-36m-darwin.so -fopenmp
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_d34791f82efcf31cce664073d73b50a7.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
print('sum2d_cython_parallel sum:', sum2d_cython_parallel(a))

t_sum2d_cython_parallel = %timeit -o sum2d_cython_parallel(a)
# Out:
# sum2d_cython_parallel sum: -2661.3591452099963
# 492 ms ± 15.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Another major performance improvement:

# %%
print(('X{:.2f} Boost relative to pure python and\n'
       'X{:.2f} Boost relative to the non-parallel cython implementation.').format(
    t_sum2d_python.average / t_sum2d_cython_parallel.average, t_sum2d_cython1.average / t_sum2d_cython_parallel.average))
# Out:
# X194.27 Boost relative to pure python and
# X2.87 Boost relative to the non-parallel cython implementation.

# %% [markdown]
# Let's see what happens if we break out the exterior loop in `sum2d_cython_parallel` and group it with the interior loop in `sum1d_cython_paralle`.

# %%
# %%cython -a -f -3 --verbose --compile-args=-fopenmp --link-args=-fopenmp
# #cython: boundscheck=False
#
# cimport cython
# from cython.parallel cimport prange
#
# cdef double p_sum2d(double [:, :] a2d, int M, int N) nogil:
#     """
#     Parallel sum all elements of a 2D array ``a2d``.
#     """
#     cdef:
#         int i, j
#         double s_ = 0
#
#     for i in prange(M):
#         for j in prange(N):
#             s_ += a2d[i, j]
#     return s_
#
# def sum2d_cython_parallel1(double [:, :] a2d):
#     """
#     Sum all elements of a 2D array ``a2d``.
#
#     Parameters
#     ----------
#     a2d : array-like
#         A 2D array to sum element by element.
#
#     Returns
#     -------
#     sum : float
#         The total sum of ``a2d``.
#     """
#     cdef:
#         int M, N
#
#     M = a2d.shape[0]
#     N = a2d.shape[1]
#     return p_sum2d(a2d, M, N)
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_172d1678c743763c5ac597deeae38b62.pyx
# building '_cython_magic_172d1678c743763c5ac597deeae38b62' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_172d1678c743763c5ac597deeae38b62.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_172d1678c743763c5ac597deeae38b62.o -fopenmp
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_172d1678c743763c5ac597deeae38b62.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_172d1678c743763c5ac597deeae38b62.cpython-36m-darwin.so -fopenmp
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_172d1678c743763c5ac597deeae38b62.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
print('sum2d_cython_parallel1 sum:', sum2d_cython_parallel1(a))

t_sum2d_cython_parallel1 = %timeit -o sum2d_cython_parallel1(a)
# Out:
# sum2d_cython_parallel1 sum: -2661.3591452130113
# 319 ms ± 9.68 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# A slight performance boost relative to the previous parallel cython implementation:

# %%
print('X{:.2f}'.format(
    t_sum2d_cython_parallel.average / t_sum2d_cython_parallel1.average))
# Out:
# X1.55

# %% [markdown]
# I don't think there is more we can do here but we are already doing better than Numpy itself so i think we did a *pretty good job*.

# %%
t_sum2d_numpy = %timeit -o a.sum()
# Out:
# 484 ms ± 13 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Another thing worth mentioning is that because of memory layout, there is a difference if you loop first over rows and then over columns or vise versa. If we change the loop order in `double p_sum2d` from :
#
# ```python
# ...
#     for i in prange(M):
#         for j in prange(N):
#             s_ += a2d[i, j]
# ...
# ```
# to:
# ```python
# ...
#     for j in prange(N):
#         for i in prange(M):
#             s_ += a2d[i, j]
# ...
# ```
#
# there is going to be a **significant difference**.

# %%
# %%cython -a -f -3 --verbose --compile-args=-fopenmp --link-args=-fopenmp
# #cython: boundscheck=False
#
# cimport cython
# from cython.parallel cimport prange
#
# cdef double p_sum2d(double [:, :] a2d, int M, int N) nogil:
#     """
#     Parallel sum all elements of a 2D array ``a2d``.
#     """
#     cdef:
#         int i, j
#         double s_ = 0
#
#     for j in prange(N):
#         for i in prange(M):
#             s_ += a2d[i, j]
#     return s_
#
# def sum2d_cython_parallel2(double [:, :] a2d):
#     """
#     Sum all elements of a 2D array ``a2d``.
#
#     Parameters
#     ----------
#     a2d : array-like
#         A 2D array to sum element by element.
#
#     Returns
#     -------
#     sum : float
#         The total sum of ``a2d``.
#     """
#     cdef:
#         int M, N
#
#     M = a2d.shape[0]
#     N = a2d.shape[1]
#     return p_sum2d(a2d, M, N)
# Out:
# [1/1] Cythonizing /Users/shahar/.ipython/cython/_cython_magic_058929016988ada89408543f9e99dced.pyx
# building '_cython_magic_058929016988ada89408543f9e99dced' extension
# gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/include -arch x86_64 -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/lib/python3.6/site-packages/numpy/core/include -I/Users/shahar/anaconda3/include/python3.6m -c /Users/shahar/.ipython/cython/_cython_magic_058929016988ada89408543f9e99dced.c -o /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_058929016988ada89408543f9e99dced.o -fopenmp
# gcc -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -Wl,-rpath,/Users/shahar/anaconda3/lib -L/Users/shahar/anaconda3/lib -headerpad_max_install_names -arch x86_64 /Users/shahar/.ipython/cython/Users/shahar/.ipython/cython/_cython_magic_058929016988ada89408543f9e99dced.o -L/Users/shahar/anaconda3/lib -o /Users/shahar/.ipython/cython/_cython_magic_058929016988ada89408543f9e99dced.cpython-36m-darwin.so -fopenmp
# <!DOCTYPE html>
# <!-- Generated by Cython 0.28.1 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_058929016988ada89408543f9e99dced.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
print('sum2d_cython_parallel2 sum:', sum2d_cython_parallel2(a))

t_sum2d_cython_parallel2 = %timeit -o sum2d_cython_parallel2(a)
# Out:
# sum2d_cython_parallel2 sum: -2661.359145210745
# 18.2 s ± 250 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Also note that if the outer loop is much larger than the inner loop then performance is also decreased. It might make sense to transpose an array in some cases and definitely worth taking the time to design your algorithm to best handle your data structure.

# %%
a_T = np.ascontiguousarray(a.T)

# %%
print('a.shape =', a.shape)
print('sum2d_cython_parallel1 sum:', sum2d_cython_parallel1(a))
t_sum2d_small_over_large = %timeit -o sum2d_cython_parallel1(a)

print()

print('a_T.shape =', a_T.shape)
print('sum2d_cython_parallel1 sum:', sum2d_cython_parallel1(a_T))

t_sum2d_large_over_small = %timeit -o sum2d_cython_parallel1(a_T)
# Out:
# a.shape = (10000, 100000)
# sum2d_cython_parallel1 sum: -2661.3591452130113
# 330 ms ± 22.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# a_T.shape = (100000, 10000)
# sum2d_cython_parallel1 sum: -2661.359145210745
# The slowest run took 14.86 times longer than the fastest. This could mean that an intermediate result is being cached.
# 990 ms ± 1.54 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numba as nb
@nb.njit(nb.float64(nb.float64[:, :]), parallel=True)
def sum2d_numba(a2d):
    """
    Sum all elements of a 2D array ``a2d``.
    
    Parameters
    ----------
    a2d : array-like
        A 2D array to sum element by element.
        
    Returns
    -------
    sum : float
        The total sum of ``a2d``.
    """
    M, N = a2d.shape
    sum_ = 0
    for i in nb.prange(M):
        for j in nb.prange(N):
            sum_ += a2d[i, j]
    return sum_

# %%
print('sum2d_numba sum:', sum2d_numba(a))

t_sum2d_numba = %timeit -o sum2d_numba(a)
# Out:
# sum2d_numba sum: -2661.359145213011
# The slowest run took 5.58 times longer than the fastest. This could mean that an intermediate result is being cached.
# 709 ms ± 538 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Here as well, Numba is doing quite well too.

# %%
timings = [t_sum2d_python.average,
           t_sum2d_cython1.average,
           t_sum2d_cython2.average,
           t_sum2d_cython_parallel.average,
           t_sum2d_cython_parallel1.average,
           t_sum2d_cython_parallel2.average,
           t_sum2d_numba.average,
           t_sum2d_numpy.average]

t = ['{:.2e}'.format(t) for t in timings]

x = ['{:.2f}'.format(timings[0] / t) for t in timings]

imp = ['Python', 'Cython1', 'Cython2', 'Parallel',
       'Parallel1', 'Parallel2', 'Numba', 'Numpy']

hline = '-' * 44
layout = '| {:<14} | {:>10} | {:>10} |'
print(hline)
print(layout.format('Implementation', 't, seconds', 'boost, X'))
print(hline)

for imp_, t_, x_ in zip(imp, t, x):
      print(layout.format(imp_, t_, x_))
            
print(hline)
# Out:
# --------------------------------------------
# | Implementation | t, seconds |   boost, X |
# --------------------------------------------
# | Python         |   9.57e+01 |       1.00 |
# | Cython1        |   1.41e+00 |      67.67 |
# | Cython2        |   1.37e+00 |      70.00 |
# | Parallel       |   4.92e-01 |     194.27 |
# | Parallel1      |   3.19e-01 |     300.25 |
# | Parallel2      |   1.82e+01 |       5.24 |
# | Numba          |   7.09e-01 |     134.88 |
# | Numpy          |   4.84e-01 |     197.51 |
# --------------------------------------------
